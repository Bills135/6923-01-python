# %%
# This is a sample Python script.

# Press Shift+F10 to execute it or replace it with your code.
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.


def print_hi(name):
    # Use a breakpoint in the code line below to debug your script.
    print(f'Hi, {name}')  # Press Ctrl+F8 to toggle the breakpoint.


# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    print_hi('PyCharm k003')

# See PyCharm help at https://www.jetbrains.com/help/pycharm/

from tensorflow.keras.datasets import mnist

(train_images,train_labels), (test_images,test_labels) = mnist.load_data()

print(train_images.shape)
print(len(train_labels))

# start
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512,activation="relu"),
    layers.Dense(10,activation="softmax")
])

model.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype('float32')/255

test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255

model.fit(train_images,train_labels,epochs=5,batch_size=128)

test_digits = test_images[0:10]
predictions = model.predict(test_digits)

print(predictions[0])
print(predictions[0].argmax())
print(predictions[0][7])
print(test_labels[0])
# Out:
# Hi, PyCharm k003
# (60000, 28, 28)
# 60000
# Epoch 1/5
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2621 - accuracy: 0.9236
# Epoch 2/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1043 - accuracy: 0.9689
# Epoch 3/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0682 - accuracy: 0.9791
# Epoch 4/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0497 - accuracy: 0.9852
# Epoch 5/5
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0370 - accuracy: 0.9889
# 1/1 [==============================] - 0s 127ms/step
# [9.6326280e-09 8.8180512e-11 6.7036276e-06 8.2517035e-05 3.3783823e-11
#  9.6878530e-08 2.1999888e-13 9.9990946e-01 9.4457974e-08 1.1364925e-06]
# 7
# 0.99990946
# 7

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (49.2.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.3.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.3)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2021.10.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
# This is a sample Python script.

# Press Shift+F10 to execute it or replace it with your code.
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.


def print_hi(name):
    # Use a breakpoint in the code line below to debug your script.
    print(f'Hi, {name}')  # Press Ctrl+F8 to toggle the breakpoint.


# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    print_hi('PyCharm k002')

# See PyCharm help at https://www.jetbrains.com/help/pycharm/

from tensorflow.keras.datasets import mnist

(train_images,train_labels), (test_images,test_labels) = mnist.load_data()

print(train_images.shape)
print(len(train_labels))

# start
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(512,activation="relu"),
    layers.Dense(10,activation="softmax")
])

model.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype('float32')/255

test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255

model.fit(train_images,train_labels,epochs=5,batch_size=128)

test_digits = test_images[0:10]
predictions = model.predict(test_digits)

print(predictions[0])
print(predictions[0].argmax())
print(predictions[0][7])
print(test_labels[0])
# Out:
# Hi, PyCharm k002
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 18
#      14     print_hi('PyCharm k002')
#      16 # See PyCharm help at https://www.jetbrains.com/help/pycharm/
# ---> 18 from tensorflow.keras.datasets import mnist
#      20 (train_images,train_labels), (test_images,test_labels) = mnist.load_data()
#      22 print(train_images.shape)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.10.0

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: setuptools in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (49.2.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.5.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.3.3)
# Requirement already satisfied: packaging in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.4)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.0.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\bill\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\Miniconda3\python.exe

# %%
import sys
# !conda install --yes --prefix {sys.prefix} tensorflow
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... done
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Miniconda3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _tflow_select-2.3.0        |              mkl           3 KB  defaults
#     absl-py-1.4.0              |     pyhd8ed1ab_0         100 KB  conda-forge
#     aiohttp-3.8.4              |  py310h8d17308_0         401 KB  conda-forge
#     aiosignal-1.3.1            |     pyhd8ed1ab_0          12 KB  conda-forge
#     astunparse-1.6.3           |     pyhd8ed1ab_0          15 KB  conda-forge
#     async-timeout-4.0.2        |     pyhd8ed1ab_0           9 KB  conda-forge
#     attrs-22.2.0               |     pyh71513ae_0          53 KB  conda-forge
#     blinker-1.5                |     pyhd8ed1ab_0          15 KB  conda-forge
#     c-ares-1.18.1              |       h8ffe710_0         114 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     cachetools-5.3.0           |     pyhd8ed1ab_0          14 KB  conda-forge
#     click-8.1.3                | win_pyhd8ed1ab_2          75 KB  conda-forge
#     cryptography-39.0.0        |  py310h52f42fa_0         984 KB  conda-forge
#     flatbuffers-23.3.3         |       h63175ca_0         1.6 MB  conda-forge
#     frozenlist-1.3.3           |  py310h8d17308_0          40 KB  conda-forge
#     gast-0.4.0                 |     pyh9f0ad1d_0          12 KB  conda-forge
#     giflib-5.2.1               |       h64bf75a_3          82 KB  conda-forge
#     google-auth-2.16.2         |     pyh1a96a4e_0          96 KB  conda-forge
#     google-auth-oauthlib-0.4.6 |     pyhd8ed1ab_0          19 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     grpc-cpp-1.48.1            |       hcb02dd0_1        28.6 MB  conda-forge
#     grpcio-1.48.1              |  py310h1177ea7_1         1.9 MB  conda-forge
#     h5py-3.8.0                 |nompi_py310h727aef9_101         842 KB  conda-forge
#     hdf5-1.14.0                |nompi_h97a5375_103         1.9 MB  conda-forge
#     icu-58.2                   |       ha925a31_3         9.4 MB  defaults
#     importlib-metadata-6.1.0   |     pyha770c72_0          24 KB  conda-forge
#     intel-openmp-2023.0.0      |   h57928b3_25922         2.1 MB  conda-forge
#     jpeg-9e                    |       hcfcfb64_3         283 KB  conda-forge
#     keras-2.10.0               |     pyhd8ed1ab_0         981 KB  conda-forge
#     krb5-1.20.1                |       h6609f42_0         699 KB  conda-forge
#     libabseil-20220623.0       | cxx17_h1a56200_6         1.3 MB  conda-forge
#     libaec-1.0.6               |       h63175ca_1          34 KB  conda-forge
#     libblas-3.9.0              |     16_win64_mkl         5.6 MB  conda-forge
#     libcblas-3.9.0             |     16_win64_mkl         5.6 MB  conda-forge
#     libcurl-7.88.1             |       h68f0423_1         303 KB  conda-forge
#     libhwloc-2.9.0             |       h51c2c0f_0         2.4 MB  conda-forge
#     libiconv-1.17              |       h8ffe710_0         698 KB  conda-forge
#     liblapack-3.9.0            |     16_win64_mkl         5.6 MB  conda-forge
#     libpng-1.6.39              |       h19919ed_0         336 KB  conda-forge
#     libprotobuf-3.20.2         |       h12be248_0         2.4 MB  conda-forge
#     libssh2-1.10.0             |       h680486a_3         228 KB  conda-forge
#     libxml2-2.10.3             |       hc3477c8_5         1.5 MB  conda-forge
#     m2w64-gcc-libgfortran-5.3.0|                6         342 KB  conda-forge
#     m2w64-gcc-libs-5.3.0       |                7         520 KB  conda-forge
#     m2w64-gcc-libs-core-5.3.0  |                7         214 KB  conda-forge
#     m2w64-gmp-6.1.0            |                2         726 KB  conda-forge
#     m2w64-libwinpthread-git-5.0.0.4634.697f757|                2          31 KB  conda-forge
#     markdown-3.4.1             |     pyhd8ed1ab_0          65 KB  conda-forge
#     markupsafe-2.1.2           |  py310h8d17308_0          25 KB  conda-forge
#     mkl-2022.1.0               |     h6a75c08_874       182.7 MB  conda-forge
#     msys2-conda-epoch-20160418 |                1           3 KB  conda-forge
#     multidict-6.0.4            |  py310h8d17308_0          48 KB  conda-forge
#     numpy-1.24.2               |  py310hd02465a_0         5.6 MB  conda-forge
#     oauthlib-3.2.2             |     pyhd8ed1ab_0          90 KB  conda-forge
#     openssl-1.1.1t             |       hcfcfb64_0         5.0 MB  conda-forge
#     opt_einsum-3.3.0           |     pyhd8ed1ab_1          53 KB  conda-forge
#     packaging-23.0             |     pyhd8ed1ab_0          40 KB  conda-forge
#     platformdirs-3.1.1         |     pyhd8ed1ab_0          17 KB  conda-forge
#     pooch-1.7.0                |     pyha770c72_1          49 KB  conda-forge
#     protobuf-3.20.2            |  py310h5588dad_1         216 KB  conda-forge
#     pthreads-win32-2.9.1       |       hfa6e2cd_3         141 KB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     pyjwt-2.6.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     python-3.10.8              |h0269646_0_cpython        14.0 MB  conda-forge
#     python-flatbuffers-23.1.21 |     pyhd8ed1ab_0          33 KB  conda-forge
#     pyu2f-0.1.5                |     pyhd8ed1ab_0          31 KB  conda-forge
#     re2-2022.06.01             |       h0e60522_1         370 KB  conda-forge
#     requests-oauthlib-1.3.1    |     pyhd8ed1ab_0          22 KB  conda-forge
#     rsa-4.9                    |     pyhd8ed1ab_0          29 KB  conda-forge
#     scipy-1.10.1               |  py310h578b7cb_0        22.5 MB  conda-forge
#     snappy-1.1.10              |       hfb803bf_0          56 KB  conda-forge
#     sqlite-3.40.0              |       hcfcfb64_0         658 KB  conda-forge
#     tbb-2021.8.0               |       h91493d7_0         150 KB  conda-forge
#     tensorboard-2.10.1         |     pyhd8ed1ab_0         5.4 MB  conda-forge
#     tensorboard-data-server-0.6.1|  py310h5588dad_4          17 KB  conda-forge
#     tensorboard-plugin-wit-1.8.1|     pyhd8ed1ab_0         668 KB  conda-forge
#     tensorflow-2.10.0          |mkl_py310hd99672f_0           4 KB  defaults
#     tensorflow-base-2.10.0     |mkl_py310h6a7f48e_0        76.1 MB  defaults
#     tensorflow-estimator-2.10.0|  py310haa95532_0         495 KB  defaults
#     termcolor-2.2.0            |     pyhd8ed1ab_0          11 KB  conda-forge
#     typing-extensions-4.5.0    |       hd8ed1ab_0           9 KB  conda-forge
#     typing_extensions-4.5.0    |     pyha770c72_0          31 KB  conda-forge
#     werkzeug-2.2.3             |     pyhd8ed1ab_0         247 KB  conda-forge
#     wrapt-1.15.0               |  py310h8d17308_0          51 KB  conda-forge
#     yarl-1.8.2                 |  py310h8d17308_0          81 KB  conda-forge
#     zipp-3.15.0                |     pyhd8ed1ab_0          17 KB  conda-forge
#     zlib-1.2.13                |       hcfcfb64_4         113 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       393.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   _tflow_select      pkgs/main/win-64::_tflow_select-2.3.0-mkl
#   absl-py            conda-forge/noarch::absl-py-1.4.0-pyhd8ed1ab_0
#   aiohttp            conda-forge/win-64::aiohttp-3.8.4-py310h8d17308_0
#   aiosignal          conda-forge/noarch::aiosignal-1.3.1-pyhd8ed1ab_0
#   astunparse         conda-forge/noarch::astunparse-1.6.3-pyhd8ed1ab_0
#   async-timeout      conda-forge/noarch::async-timeout-4.0.2-pyhd8ed1ab_0
#   attrs              conda-forge/noarch::attrs-22.2.0-pyh71513ae_0
#   blinker            conda-forge/noarch::blinker-1.5-pyhd8ed1ab_0
#   c-ares             conda-forge/win-64::c-ares-1.18.1-h8ffe710_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   cachetools         conda-forge/noarch::cachetools-5.3.0-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.1.3-win_pyhd8ed1ab_2
#   flatbuffers        conda-forge/win-64::flatbuffers-23.3.3-h63175ca_0
#   frozenlist         conda-forge/win-64::frozenlist-1.3.3-py310h8d17308_0
#   gast               conda-forge/noarch::gast-0.4.0-pyh9f0ad1d_0
#   giflib             conda-forge/win-64::giflib-5.2.1-h64bf75a_3
#   google-auth        conda-forge/noarch::google-auth-2.16.2-pyh1a96a4e_0
#   google-auth-oauth~ conda-forge/noarch::google-auth-oauthlib-0.4.6-pyhd8ed1ab_0
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   grpc-cpp           conda-forge/win-64::grpc-cpp-1.48.1-hcb02dd0_1
#   grpcio             conda-forge/win-64::grpcio-1.48.1-py310h1177ea7_1
#   h5py               conda-forge/win-64::h5py-3.8.0-nompi_py310h727aef9_101
#   hdf5               conda-forge/win-64::hdf5-1.14.0-nompi_h97a5375_103
#   icu                pkgs/main/win-64::icu-58.2-ha925a31_3
#   importlib-metadata conda-forge/noarch::importlib-metadata-6.1.0-pyha770c72_0
#   intel-openmp       conda-forge/win-64::intel-openmp-2023.0.0-h57928b3_25922
#   jpeg               conda-forge/win-64::jpeg-9e-hcfcfb64_3
#   keras              conda-forge/noarch::keras-2.10.0-pyhd8ed1ab_0
#   krb5               conda-forge/win-64::krb5-1.20.1-h6609f42_0
#   libabseil          conda-forge/win-64::libabseil-20220623.0-cxx17_h1a56200_6
#   libaec             conda-forge/win-64::libaec-1.0.6-h63175ca_1
#   libblas            conda-forge/win-64::libblas-3.9.0-16_win64_mkl
#   libcblas           conda-forge/win-64::libcblas-3.9.0-16_win64_mkl
#   libcurl            conda-forge/win-64::libcurl-7.88.1-h68f0423_1
#   libhwloc           conda-forge/win-64::libhwloc-2.9.0-h51c2c0f_0
#   libiconv           conda-forge/win-64::libiconv-1.17-h8ffe710_0
#   liblapack          conda-forge/win-64::liblapack-3.9.0-16_win64_mkl
#   libpng             conda-forge/win-64::libpng-1.6.39-h19919ed_0
#   libprotobuf        conda-forge/win-64::libprotobuf-3.20.2-h12be248_0
#   libssh2            conda-forge/win-64::libssh2-1.10.0-h680486a_3
#   libxml2            conda-forge/win-64::libxml2-2.10.3-hc3477c8_5
#   m2w64-gcc-libgfor~ conda-forge/win-64::m2w64-gcc-libgfortran-5.3.0-6
#   m2w64-gcc-libs     conda-forge/win-64::m2w64-gcc-libs-5.3.0-7
#   m2w64-gcc-libs-co~ conda-forge/win-64::m2w64-gcc-libs-core-5.3.0-7
#   m2w64-gmp          conda-forge/win-64::m2w64-gmp-6.1.0-2
#   m2w64-libwinpthre~ conda-forge/win-64::m2w64-libwinpthread-git-5.0.0.4634.697f757-2
#   markdown           conda-forge/noarch::markdown-3.4.1-pyhd8ed1ab_0
#   markupsafe         conda-forge/win-64::markupsafe-2.1.2-py310h8d17308_0
#   mkl                conda-forge/win-64::mkl-2022.1.0-h6a75c08_874
#   msys2-conda-epoch  conda-forge/win-64::msys2-conda-epoch-20160418-1
#   multidict          conda-forge/win-64::multidict-6.0.4-py310h8d17308_0
#   numpy              conda-forge/win-64::numpy-1.24.2-py310hd02465a_0
#   oauthlib           conda-forge/noarch::oauthlib-3.2.2-pyhd8ed1ab_0
#   opt_einsum         conda-forge/noarch::opt_einsum-3.3.0-pyhd8ed1ab_1
#   packaging          conda-forge/noarch::packaging-23.0-pyhd8ed1ab_0
#   platformdirs       conda-forge/noarch::platformdirs-3.1.1-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.7.0-pyha770c72_1
#   protobuf           conda-forge/win-64::protobuf-3.20.2-py310h5588dad_1
#   pthreads-win32     conda-forge/win-64::pthreads-win32-2.9.1-hfa6e2cd_3
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   pyjwt              conda-forge/noarch::pyjwt-2.6.0-pyhd8ed1ab_0
#   python-flatbuffers conda-forge/noarch::python-flatbuffers-23.1.21-pyhd8ed1ab_0
#   pyu2f              conda-forge/noarch::pyu2f-0.1.5-pyhd8ed1ab_0
#   re2                conda-forge/win-64::re2-2022.06.01-h0e60522_1
#   requests-oauthlib  conda-forge/noarch::requests-oauthlib-1.3.1-pyhd8ed1ab_0
#   rsa                conda-forge/noarch::rsa-4.9-pyhd8ed1ab_0
#   scipy              conda-forge/win-64::scipy-1.10.1-py310h578b7cb_0
#   snappy             conda-forge/win-64::snappy-1.1.10-hfb803bf_0
#   sqlite             conda-forge/win-64::sqlite-3.40.0-hcfcfb64_0
#   tbb                conda-forge/win-64::tbb-2021.8.0-h91493d7_0
#   tensorboard        conda-forge/noarch::tensorboard-2.10.1-pyhd8ed1ab_0
#   tensorboard-data-~ conda-forge/win-64::tensorboard-data-server-0.6.1-py310h5588dad_4
#   tensorboard-plugi~ conda-forge/noarch::tensorboard-plugin-wit-1.8.1-pyhd8ed1ab_0
#   tensorflow         pkgs/main/win-64::tensorflow-2.10.0-mkl_py310hd99672f_0
#   tensorflow-base    pkgs/main/win-64::tensorflow-base-2.10.0-mkl_py310h6a7f48e_0
#   tensorflow-estima~ pkgs/main/win-64::tensorflow-estimator-2.10.0-py310haa95532_0
#   termcolor          conda-forge/noarch::termcolor-2.2.0-pyhd8ed1ab_0
#   typing-extensions  conda-forge/noarch::typing-extensions-4.5.0-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.5.0-pyha770c72_0
#   werkzeug           conda-forge/noarch::werkzeug-2.2.3-pyhd8ed1ab_0
#   wrapt              conda-forge/win-64::wrapt-1.15.0-py310h8d17308_0
#   yarl               conda-forge/win-64::yarl-1.8.2-py310h8d17308_0
#   zipp               conda-forge/noarch::zipp-3.15.0-pyhd8ed1ab_0
#   zlib               conda-forge/win-64::zlib-1.2.13-hcfcfb64_4
#
# The following packages will be DOWNGRADED:
#
#   cryptography                       39.0.2-py310h6e82f81_0 --> 39.0.0-py310h52f42fa_0
#   openssl                                  3.1.0-hcfcfb64_0 --> 1.1.1t-hcfcfb64_0
#   python                          3.10.9-h4de0772_0_cpython --> 3.10.8-h0269646_0_cpython
#
#
#
# Downloading and Extracting Packages
#
# m2w64-gcc-libs-5.3.0 | 520 KB    |            |   0%
#
# snappy-1.1.10        | 56 KB     |            |   0%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   |            |   0%
#
#
#
# yarl-1.8.2           | 81 KB     |            |   0%
#
#
#
#
# cryptography-39.0.0  | 984 KB    |            |   0%
#
#
#
#
#
# numpy-1.24.2         | 5.6 MB    |            |   0%
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    |            |   0%
#
#
#
#
#
#
#
# cached-property-1.5. | 4 KB      |            |   0%
#
#
#
#
#
#
#
#
# tensorflow-2.10.0    | 4 KB      |            |   0%
#
#
#
#
#
#
#
#
#
# google-auth-oauthlib | 19 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# libiconv-1.17        | 698 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# typing-extensions-4. | 9 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.10.0       | 228 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 981 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 283 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.8.4        | 401 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-6 | 24 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opt_einsum-3.3.0     | 53 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# m2w64-gcc-libs-5.3.0 | 520 KB    | 3          |   3%
#
# snappy-1.1.10        | 56 KB     | ##8        |  29%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   |            |   0%
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | 2          |   2%
#
#
#
#
# cryptography-39.0.0  | 984 KB    | 1          |   2%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   |            |   1%
#
#
#
#
#
#
#
# cached-property-1.5. | 4 KB      | ########## | 100%
#
#
#
#
#
# numpy-1.24.2         | 5.6 MB    |            |   0%
#
#
#
#
# cryptography-39.0.0  | 984 KB    | #1         |  11%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | 1          |   2%
#
# snappy-1.1.10        | 56 KB     | ########## | 100%
#
# snappy-1.1.10        | 56 KB     | ########## | 100%
#
#
#
#
#
# numpy-1.24.2         | 5.6 MB    | #8         |  18%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | 2          |   3%
#
#
#
#
#
#
#
# cached-property-1.5. | 4 KB      | ########## | 100%
#
#
#
#
# cryptography-39.0.0  | 984 KB    | #9         |  20%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ########## | 100%
# m2w64-gcc-libs-5.3.0 | 520 KB    | ########## | 100%
#
#
#
#
#
# numpy-1.24.2         | 5.6 MB    | ###6       |  36%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | 3          |   4%
#
#
#
#
# cryptography-39.0.0  | 984 KB    | ##9        |  29%
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | ########## | 100%
#
#
#
#
#
#
# m2w64-gmp-6.1.0      | 726 KB    | ########## | 100%
#
#
#
#
#
# numpy-1.24.2         | 5.6 MB    | #####3     |  53%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | 6          |   6%
#
#
#
#
# cryptography-39.0.0  | 984 KB    | #####2     |  52%
#
#
#
#
#
# numpy-1.24.2         | 5.6 MB    | ######9    |  69%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | 8          |   8%
#
#
#
#
# cryptography-39.0.0  | 984 KB    | #######8   |  78%
#
#
#
#
#
# numpy-1.24.2         | 5.6 MB    | ########4  |  85%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #1         |  11%
#
#
#
#
#
#
#
#
#
#
# libiconv-1.17        | 698 KB    | 2          |   2%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
# typing-extensions-4. | 9 KB      | ########## | 100%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #8         |  18%
#
#
#
# yarl-1.8.2           | 81 KB     | #9         |  20%
#
#
#
#
#
#
#
#
# tensorflow-2.10.0    | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.10.0       | 228 KB    | 7          |   7%
#
#
#
#
#
#
#
#
#
# google-auth-oauthlib | 19 KB     | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 981 KB    | 1          |   2%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-6 | 24 KB     | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 981 KB    | #########9 |  99%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opt_einsum-3.3.0     | 53 KB     | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 283 KB    | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.8.4        | 401 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
# libiconv-1.17        | 698 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libiconv-1.17        | 698 KB    | ########## | 100%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    | ####7      |  48%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ###3       |  33%
#
#
#
#
#
#
#
#
#
#
#
# typing-extensions-4. | 9 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.8.4        | 401 KB    | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    | ######4    |  64%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.8.4        | 401 KB    | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    | ########1  |  81%
#
#
#
#
#
#
#
#
# tensorflow-2.10.0    | 4 KB      | ########## | 100%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ###9       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    | #########7 |  97%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ####1      |  42%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
#
# google-auth-oauthlib | 19 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# google-auth-oauthlib | 19 KB     | ########## | 100%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ####7      |  47%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ####9      |  50%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #####2     |  53%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #####5     |  56%
#
#
#
# yarl-1.8.2           | 81 KB     | ########## | 100%
#
#
#
# yarl-1.8.2           | 81 KB     | ########## | 100%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #####8     |  59%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ######1    |  62%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ######4    |  65%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ######7    |  68%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #######    |  71%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #######3   |  73%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #######6   |  76%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #######9   |  79%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ########2  |  83%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ########5  |  86%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ########8  |  89%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #########1 |  92%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #########4 |  95%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | #########7 |  98%
#
#
#
#
# cryptography-39.0.0  | 984 KB    | ########## | 100%
#
#
#
#
# cryptography-39.0.0  | 984 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-6 | 24 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib-metadata-6 | 24 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.10.0       | 228 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libssh2-1.10.0       | 228 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opt_einsum-3.3.0     | 53 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# opt_einsum-3.3.0     | 53 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 283 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 283 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.8.4        | 401 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aiohttp-3.8.4        | 401 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 5.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# keras-2.10.0         | 981 KB    | ########## | 100%
#
#
#
#
#
# numpy-1.24.2         | 5.6 MB    | ########## | 100%
#
#
# grpc-cpp-1.48.1      | 28.6 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
